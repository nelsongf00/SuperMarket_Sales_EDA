# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("supermarket_sales - Sheet1.csv")
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
df.shape # How Many Rows and colomns?
# Out:
# (1000, 17)

# %%
df.info() # Types of Data and check for non null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df = df.drop("Branch",axis = 1) # Drop unnecessary colomns

# %%
df["Date"] = pd.to_datetime(df["Date"]) # Convert Date colomn from string type to date type

# %%
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["Hour"] = df["Time"].str[0:2] # Add a new coloum named hour
df.head()
# Out:
#     Invoice ID       City Customer type  Gender            Product line  \
# 0  750-67-8428     Yangon        Member  Female       Health and beauty
# 1  226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 2  631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176     Yangon        Member    Male       Health and beauty
# 4  373-73-7910     Yangon        Normal    Male       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08      Ewallet
# 1       15.28         5   3.8200   80.2200 2019-03-08  10:29         Cash
# 2       46.33         7  16.2155  340.5255 2019-03-03  13:23  Credit card
# 3       58.22         8  23.2880  489.0480 2019-01-27  20:33      Ewallet
# 4       86.31         7  30.2085  634.3785 2019-02-08  10:37      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating Hour
# 0  522.83                 4.761905       26.1415     9.1   13
# 1   76.40                 4.761905        3.8200     9.6   10
# 2  324.31                 4.761905       16.2155     7.4   13
# 3  465.76                 4.761905       23.2880     8.4   20
# 4  604.17                 4.761905       30.2085     5.3   10

# %%
df["Date"] = df["Date"].dt.strftime('%Y-%m-%d')
df["Month"] = df["Date"].str[5:7]

df["Month"].unique()

df["Month"] = df["Month"].map({"01":"January","02":"February","03": "March"})

# %%
df['Invoice ID'].is_unique # Check if Invoice Id field is unique
# Out:
# True

# %%
df.set_index("Invoice ID",inplace =True) # Make Invoice ID colomn into index

# %%
df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%     Total        Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415  548.9715  2019-01-05  13:08
# 226-31-3081       15.28         5   3.8200   80.2200  2019-03-08  10:29
# 631-41-3108       46.33         7  16.2155  340.5255  2019-03-03  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  2019-01-27  20:33
# 373-73-7910       86.31         7  30.2085  634.3785  2019-02-08  10:37
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 750-67-8428      Ewallet  522.83                 4.761905       26.1415
# 226-31-3081         Cash   76.40                 4.761905        3.8200
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
#
#              Rating Hour     Month
# Invoice ID
# 750-67-8428     9.1   13   January
# 226-31-3081     9.6   10     March
# 631-41-3108     7.4   13     March
# 123-19-1176     8.4   20   January
# 373-73-7910     5.3   10  February

# %% [markdown]
# # Gender

# %%
df["Gender"].unique() # Find unique
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Gender"].value_counts() # Total number of male and female
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
# x = df["Gender"]
# y = df.shape[0]
# plt.bar(x,y)

# %%
gb = df.groupby("Gender")
Male_df = gb.get_group("Male")
Female_df = gb.get_group("Female")
Male_df.head()
# Out:
#                   City Customer type Gender            Product line  \
# Invoice ID
# 631-41-3108     Yangon        Normal   Male      Home and lifestyle
# 123-19-1176     Yangon        Member   Male       Health and beauty
# 373-73-7910     Yangon        Normal   Male       Sports and travel
# 699-14-3026  Naypyitaw        Normal   Male  Electronic accessories
# 529-56-3974   Mandalay        Member   Male  Electronic accessories
#
#              Unit price  Quantity   Tax 5%     Total        Date   Time  \
# Invoice ID
# 631-41-3108       46.33         7  16.2155  340.5255  2019-03-03  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  2019-01-27  20:33
# 373-73-7910       86.31         7  30.2085  634.3785  2019-02-08  10:37
# 699-14-3026       85.39         7  29.8865  627.6165  2019-03-25  18:30
# 529-56-3974       25.51         4   5.1020  107.1420  2019-03-09  17:03
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
# 699-14-3026      Ewallet  597.73                 4.761905       29.8865
# 529-56-3974         Cash  102.04                 4.761905        5.1020
#
#              Rating Hour     Month
# Invoice ID
# 631-41-3108     7.4   13     March
# 123-19-1176     8.4   20   January
# 373-73-7910     5.3   10  February
# 699-14-3026     4.1   18     March
# 529-56-3974     6.8   17     March

# %%
Male_df["Product line"].value_counts()
# Out:
# Health and beauty         88
# Electronic accessories    86
# Food and beverages        84
# Fashion accessories       82
# Home and lifestyle        81
# Sports and travel         78
# Name: Product line, dtype: int64

# %%
Female_df["Product line"].value_counts()
# Out:
# Fashion accessories       96
# Food and beverages        90
# Sports and travel         88
# Electronic accessories    84
# Home and lifestyle        79
# Health and beauty         64
# Name: Product line, dtype: int64

# %%
plt.figure(figsize=(12,8))
x = Female_df["Product line"].unique()
y = Female_df["Product line"].value_counts()
plt.bar(x,y)
plt.tight_layout()

# %%
Male_df["Payment"].value_counts()
# Out:
# Ewallet        185
# Cash           166
# Credit card    148
# Name: Payment, dtype: int64

# %%
Female_df["Payment"].value_counts()
# Out:
# Cash           178
# Credit card    163
# Ewallet        160
# Name: Payment, dtype: int64

# %% [markdown]
# # City

# %%
df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df["City"].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
gb = df.groupby("City")   
Yangon_df = gb.get_group("Yangon")
Naypyitaw_df = gb.get_group("Naypyitaw")
Mandalay_df = gb.get_group("Mandalay")
Yangon_df.head()
# Out:
#                City Customer type  Gender            Product line  Unit price  \
# Invoice ID
# 750-67-8428  Yangon        Member  Female       Health and beauty       74.69
# 631-41-3108  Yangon        Normal    Male      Home and lifestyle       46.33
# 123-19-1176  Yangon        Member    Male       Health and beauty       58.22
# 373-73-7910  Yangon        Normal    Male       Sports and travel       86.31
# 355-53-5943  Yangon        Member  Female  Electronic accessories       68.84
#
#              Quantity   Tax 5%     Total        Date   Time      Payment  \
# Invoice ID
# 750-67-8428         7  26.1415  548.9715  2019-01-05  13:08      Ewallet
# 631-41-3108         7  16.2155  340.5255  2019-03-03  13:23  Credit card
# 123-19-1176         8  23.2880  489.0480  2019-01-27  20:33      Ewallet
# 373-73-7910         7  30.2085  634.3785  2019-02-08  10:37      Ewallet
# 355-53-5943         6  20.6520  433.6920  2019-02-25  14:36      Ewallet
#
#                cogs  gross margin percentage  gross income  Rating Hour  \
# Invoice ID
# 750-67-8428  522.83                 4.761905       26.1415     9.1   13
# 631-41-3108  324.31                 4.761905       16.2155     7.4   13
# 123-19-1176  465.76                 4.761905       23.2880     8.4   20
# 373-73-7910  604.17                 4.761905       30.2085     5.3   10
# 355-53-5943  413.04                 4.761905       20.6520     5.8   14
#
#                 Month
# Invoice ID
# 750-67-8428   January
# 631-41-3108     March
# 123-19-1176   January
# 373-73-7910  February
# 355-53-5943  February

# %%
Naypyitaw_df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 699-14-3026  Naypyitaw        Normal    Male  Electronic accessories
# 315-22-5665  Naypyitaw        Normal  Female      Home and lifestyle
# 300-71-4605  Naypyitaw        Member    Male  Electronic accessories
# 183-56-6882  Naypyitaw        Member  Female      Food and beverages
#
#              Unit price  Quantity   Tax 5%     Total        Date   Time  \
# Invoice ID
# 226-31-3081       15.28         5   3.8200   80.2200  2019-03-08  10:29
# 699-14-3026       85.39         7  29.8865  627.6165  2019-03-25  18:30
# 315-22-5665       73.56        10  36.7800  772.3800  2019-02-24  11:38
# 300-71-4605       86.04         5  21.5100  451.7100  2019-02-25  11:24
# 183-56-6882       99.42         4  19.8840  417.5640  2019-02-06  10:42
#
#              Payment    cogs  gross margin percentage  gross income  Rating  \
# Invoice ID
# 226-31-3081     Cash   76.40                 4.761905        3.8200     9.6
# 699-14-3026  Ewallet  597.73                 4.761905       29.8865     4.1
# 315-22-5665  Ewallet  735.60                 4.761905       36.7800     8.0
# 300-71-4605  Ewallet  430.20                 4.761905       21.5100     4.8
# 183-56-6882  Ewallet  397.68                 4.761905       19.8840     7.5
#
#             Hour     Month
# Invoice ID
# 226-31-3081   10     March
# 699-14-3026   18     March
# 315-22-5665   11  February
# 300-71-4605   11  February
# 183-56-6882   10  February

# %%
Mandalay_df.head()
# Out:
#                  City Customer type  Gender            Product line  \
# Invoice ID
# 692-92-5582  Mandalay        Member  Female      Food and beverages
# 351-62-0822  Mandalay        Member  Female     Fashion accessories
# 529-56-3974  Mandalay        Member    Male  Electronic accessories
# 299-46-1805  Mandalay        Member  Female       Sports and travel
# 319-50-3348  Mandalay        Normal  Female      Home and lifestyle
#
#              Unit price  Quantity  Tax 5%    Total        Date   Time  \
# Invoice ID
# 692-92-5582       54.84         3   8.226  172.746  2019-02-20  13:27
# 351-62-0822       14.48         4   2.896   60.816  2019-02-06  18:07
# 529-56-3974       25.51         4   5.102  107.142  2019-03-09  17:03
# 299-46-1805       93.72         6  28.116  590.436  2019-01-15  16:19
# 319-50-3348       40.30         2   4.030   84.630  2019-03-11  15:30
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 692-92-5582  Credit card  164.52                 4.761905         8.226
# 351-62-0822      Ewallet   57.92                 4.761905         2.896
# 529-56-3974         Cash  102.04                 4.761905         5.102
# 299-46-1805         Cash  562.32                 4.761905        28.116
# 319-50-3348      Ewallet   80.60                 4.761905         4.030
#
#              Rating Hour     Month
# Invoice ID
# 692-92-5582     5.9   13  February
# 351-62-0822     4.5   18  February
# 529-56-3974     6.8   17     March
# 299-46-1805     4.5   16   January
# 319-50-3348     4.4   15     March

# %%
Mandalay_df["gross income"].sum()
# Out:
# 5057.032

# %%
Naypyitaw_df["gross income"].sum()
# Out:
# 5265.1765

# %%
Yangon_df["gross income"].sum()
# Out:
# 5057.1605

# %%
Mandalay_df["Product line"].value_counts()
# Out:
# Fashion accessories       62
# Sports and travel         62
# Electronic accessories    55
# Health and beauty         53
# Food and beverages        50
# Home and lifestyle        50
# Name: Product line, dtype: int64

# %%
Naypyitaw_df["Product line"].value_counts()
# Out:
# Food and beverages        66
# Fashion accessories       65
# Electronic accessories    55
# Health and beauty         52
# Home and lifestyle        45
# Sports and travel         45
# Name: Product line, dtype: int64

# %%
Yangon_df["Product line"].value_counts()
# Out:
# Home and lifestyle        65
# Electronic accessories    60
# Sports and travel         59
# Food and beverages        58
# Fashion accessories       51
# Health and beauty         47
# Name: Product line, dtype: int64

# %% [markdown]
# # Payment

# %%
df["Payment"].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
Mandalay_df["Payment"].value_counts()
# Out:
# Ewallet        113
# Cash           110
# Credit card    109
# Name: Payment, dtype: int64

# %%
Yangon_df["Payment"].value_counts()
# Out:
# Ewallet        126
# Cash           110
# Credit card    104
# Name: Payment, dtype: int64

# %%
Naypyitaw_df["Payment"].value_counts()
# Out:
# Cash           124
# Ewallet        106
# Credit card     98
# Name: Payment, dtype: int64

# %%
df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%     Total        Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415  548.9715  2019-01-05  13:08
# 226-31-3081       15.28         5   3.8200   80.2200  2019-03-08  10:29
# 631-41-3108       46.33         7  16.2155  340.5255  2019-03-03  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  2019-01-27  20:33
# 373-73-7910       86.31         7  30.2085  634.3785  2019-02-08  10:37
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 750-67-8428      Ewallet  522.83                 4.761905       26.1415
# 226-31-3081         Cash   76.40                 4.761905        3.8200
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
#
#              Rating Hour     Month
# Invoice ID
# 750-67-8428     9.1   13   January
# 226-31-3081     9.6   10     March
# 631-41-3108     7.4   13     March
# 123-19-1176     8.4   20   January
# 373-73-7910     5.3   10  February

# %%
# x = Naypyitaw_df["gross income"]
# y = Yangon_df["gross income"]
# z = Mandalay_df["gross income"]
# plt.figure(figsize=(12,7))
# plt.plot(x,y)

# %%
# df["Date"] = df["Date"].dt.strftime('%Y-%m-%d')
# df["Month"] = df["Date"].str[5:7]
# df["Month"] = df["Date"].str[5:7]
# df["Month"].unique()

# %%
df["Month"] = df["Date"].str[5:7]
df["Month"].unique()
# Out:
# array(['01', '03', '02'], dtype=object)

# %%
df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%     Total        Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415  548.9715  2019-01-05  13:08
# 226-31-3081       15.28         5   3.8200   80.2200  2019-03-08  10:29
# 631-41-3108       46.33         7  16.2155  340.5255  2019-03-03  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  2019-01-27  20:33
# 373-73-7910       86.31         7  30.2085  634.3785  2019-02-08  10:37
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 750-67-8428      Ewallet  522.83                 4.761905       26.1415
# 226-31-3081         Cash   76.40                 4.761905        3.8200
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
#
#              Rating Hour Month
# Invoice ID
# 750-67-8428     9.1   13    01
# 226-31-3081     9.6   10    03
# 631-41-3108     7.4   13    03
# 123-19-1176     8.4   20    01
# 373-73-7910     5.3   10    02

# %%
df["Month"] = df["Month"].map({"01":"January","02":"February","03": "March"})

# %%
df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%     Total        Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415  548.9715  2019-01-05  13:08
# 226-31-3081       15.28         5   3.8200   80.2200  2019-03-08  10:29
# 631-41-3108       46.33         7  16.2155  340.5255  2019-03-03  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  2019-01-27  20:33
# 373-73-7910       86.31         7  30.2085  634.3785  2019-02-08  10:37
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 750-67-8428      Ewallet  522.83                 4.761905       26.1415
# 226-31-3081         Cash   76.40                 4.761905        3.8200
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
#
#              Rating Hour     Month
# Invoice ID
# 750-67-8428     9.1   13   January
# 226-31-3081     9.6   10     March
# 631-41-3108     7.4   13     March
# 123-19-1176     8.4   20   January
# 373-73-7910     5.3   10  February
